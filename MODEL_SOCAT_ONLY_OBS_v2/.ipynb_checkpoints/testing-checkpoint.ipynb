# %%
import pandas as pd


socat_path = (
    "/remote/unity/bgc-output/DELAIGUE/SOCAT-FLOATS-OSSE/MODEL_SOCAT_ONLY_OBS_v2/models/30S/MC_ensemble//independent_predictions/MC_independent_validation_predictions.csv"

)


test = pd.read_csv(socat_path)

# %%
test
# Out:
#      month_center  lat_center  lon_center  depth    MLD  ARMOR3D_temperature  \
# 0      1999-08-01       -67.5       145.5    0.0  15.00              -1.7950
# 1      1999-07-01       -66.5       143.5    0.0  18.70              -1.7980
# 2      1999-08-01       -66.5       143.5    0.0  15.00              -1.7980
# 3      1999-08-01       -66.5       144.5    0.0  15.00              -1.7980
# 4      1999-08-01       -66.5       145.5    0.0  15.00              -1.7970
# ...           ...         ...         ...    ...    ...                  ...
# 1596   2023-03-01       -33.5       -53.5    0.0  14.10              24.7210
# 1597   2023-03-01       -33.5       -52.5    0.0  14.70              24.1335
# 1598   2023-02-01       -33.5        17.5    0.0  13.95              18.0825
# 1599   2023-04-01       -32.5       -51.5    0.0  15.00              22.2415
# 1600   2023-04-01       -31.5       -51.5    0.0  14.90              22.5960
#
# ...
