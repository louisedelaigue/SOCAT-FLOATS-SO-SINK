# %%
import pandas as pd

df = pd.read_csv("/remote/unity/bgc-output/DELAIGUE/SOCAT-FLOATS-OSSE/MODEL_FLOATS_v2/processing_steps/BGC-Argo_SO_clean_MLD_monthly_regridded_SLA.csv")

# %%
df
# Out:
#       month_center  lat_center  lon_center  depth    MLD  ARMOR3D_temperature  \
# 0       2023-02-01       -77.5      -170.5    0.0  29.25              -0.7145
# 1       2023-11-01       -77.5      -170.5    0.0  17.50              -1.7990
# 2       2023-12-01       -77.5      -170.5    0.0  22.60              -0.3015
# 3       2024-01-01       -77.5      -170.5    0.0  20.00               0.3345
# 4       2024-02-01       -77.5      -170.5    0.0  35.65              -0.6200
# ...            ...         ...         ...    ...    ...                  ...
# 39985   2020-07-01       -30.5       158.5    0.0  75.95              20.9330
# 39986   2020-08-01       -30.5       159.5    0.0  99.85              20.3120
# 39987   2020-09-01       -30.5       160.5    0.0  67.55              19.6310
# 39988   2020-10-01       -30.5       160.5    0.0  36.90              20.8310
# 39989   2024-11-01       -30.5       172.5    0.0  18.60              20.3300
#
# ...

# %%
import pandas as pd

indep_data_path = "/remote/unity/bgc-output/DELAIGUE/SOCAT-FLOATS-OSSE/MODEL_FLOATS_v2/processing_steps/independent_validation/pco2_independent_validation_data_TSMLD_SLA_RRS_PAR_WIND_ATM_CO2_feature_engineered_monthly_1deg.csv"


indep_df = pd.read_csv(indep_data_path)

# %%
indep_df
# Out:
#      month_center  lat_center  lon_center  depth    MLD  ARMOR3D_temperature  \
# 0      2003-09-01       -35.5      -162.5    0.0  53.45              15.0620
# 1      2003-10-01       -35.5      -162.5    0.0  57.25              15.1555
# 2      2003-08-01       -35.5      -161.5    0.0  93.10              14.6435
# 3      2003-09-01       -35.5      -161.5    0.0  68.65              14.9390
# 4      2003-10-01       -35.5      -161.5    0.0  37.70              15.3255
# ...           ...         ...         ...    ...    ...                  ...
# 1291   2024-01-01       -30.5       -36.5    0.0  23.50              22.6340
# 1292   2024-02-01       -30.5       -36.5    0.0  19.30              23.7910
# 1293   2024-03-01       -30.5       -36.5    0.0  26.40              24.0830
# 1294   2024-04-01       -30.5       -36.5    0.0  40.95              22.9715
# 1295   2024-01-01       -30.5       -35.5    0.0  22.90              22.4820
#
# ...
