# %%
import pandas as pd

df = pd.read_csv("/remote/unity/bgc-output/DELAIGUE/SOCAT-FLOATS-OSSE/MODEL_FLOATS_v2/processing_steps/BGC-Argo_SO_clean_MLD_monthly_regridded_SLA.csv")

# %%
df
# Out:
#       month_center  lat_center  lon_center  depth    MLD  ARMOR3D_temperature  \
# 0       2023-02-01       -77.5      -170.5    0.0  29.25              -0.7145
# 1       2023-11-01       -77.5      -170.5    0.0  17.50              -1.7990
# 2       2023-12-01       -77.5      -170.5    0.0  22.60              -0.3015
# 3       2024-01-01       -77.5      -170.5    0.0  20.00               0.3345
# 4       2024-02-01       -77.5      -170.5    0.0  35.65              -0.6200
# ...            ...         ...         ...    ...    ...                  ...
# 39985   2020-07-01       -30.5       158.5    0.0  75.95              20.9330
# 39986   2020-08-01       -30.5       159.5    0.0  99.85              20.3120
# 39987   2020-09-01       -30.5       160.5    0.0  67.55              19.6310
# 39988   2020-10-01       -30.5       160.5    0.0  36.90              20.8310
# 39989   2024-11-01       -30.5       172.5    0.0  18.60              20.3300
#
#        ARMOR3D_salinity  FLOATS_pco2_median  FLOATS_pco2_error_median  \
# 0               34.2135          382.802002                 37.895000
# 1               34.2175          427.435501                 34.321999
# 2               34.2680          356.127502                 41.786999
# 3               34.1670          363.734009                 39.803499
# 4               34.0770          384.696487                 38.019501
# ...                 ...                 ...                       ...
# 39985           35.6800          377.696991                 32.207001
# 39986           35.6720          385.790985                 31.524000
# 39987           35.7160          368.500488                 30.045250
# 39988           35.7030          371.906006                 30.205999
# 39989           35.7220          386.671997                 27.058001
#
#        FLOATS_temperature_median  FLOATS_salinity_median  FLOATS_count  \
# 0                      -1.222001               34.122646           4.0
# 1                      -1.651704               34.394283           2.0
# 2                      -0.897576               34.370581           6.0
# 3                      -0.230904               34.226492           6.0
# 4                      -0.615187               34.235912           6.0
# ...                          ...                     ...           ...
# 39985                  19.764999               35.674915           1.0
# 39986                  21.070784               35.698017           1.0
# 39987                  19.768353               35.724983           2.0
# 39988                  20.082758               35.729160           1.0
# 39989                  20.287560               35.694969           1.0
#
#        sla_median
# 0        0.077275
# 1        0.022325
# 2        0.080950
# 3        0.057200
# 4        0.121350
# ...           ...
# 39985    0.119350
# 39986    0.226050
# 39987    0.096200
# 39988    0.104900
# 39989    0.105575
#
# [39990 rows x 13 columns]

# %%
import pandas as pd

indep_data_path = BASE_PATH + "pco2_independent_validation_data_TSMLD_SLA_RRS_PAR_WIND_ATM_CO2_feature_engineered_monthly_1deg.csv"


indep_df = pd.read_csv(indep_data_path)

# %%
indep_df
# Out:
#       month_center  lat_center  lon_center  depth    MLD  ARMOR3D_temperature  \
# 0       2003-01-01       -47.5       152.5    0.0  32.05              12.1475
# 1       2003-02-01       -47.5       152.5    0.0  52.15              12.1625
# 2       2003-04-01       -46.5       152.5    0.0  48.70              12.0540
# 3       2003-04-01       -46.5       153.5    0.0  49.65              12.1000
# 4       2003-05-01       -45.5       154.5    0.0  60.20              13.3090
# ...            ...         ...         ...    ...    ...                  ...
# 39976   2024-08-01       -30.5       106.5    0.0  86.45              17.3965
# 39977   2024-09-01       -30.5       106.5    0.0  63.20              17.7400
# 39978   2024-01-01       -30.5       112.5    0.0  29.40              22.0820
# 39979   2024-01-01       -30.5       113.5    0.0  24.80              22.5255
# 39980   2024-11-01       -30.5       172.5    0.0  18.60              20.3300
#
#        ARMOR3D_salinity  FLOATS_pco2_median  FLOATS_pco2_error_median  \
# 0               34.6345          321.730499                 19.704500
# 1               34.6275          327.389511                 18.561749
# 2               34.6915          327.755981                 18.091499
# 3               34.6625          324.366486                 17.815500
# 4               34.8705          326.507996                 19.296001
# ...                 ...                 ...                       ...
# 39976           35.8810          400.888245                 33.550858
# 39977           35.8540          399.672424                 33.701279
# 39978           35.7415          395.073990                 28.960000
# 39979           35.7005          399.710999                 29.726999
# 39980           35.7220          386.671997                 27.058001
#
#        FLOATS_temperature_median  ...  month  doy  decimal_year  doy_radians  \
# 0                      12.209000  ...      1    1   2003.000000     0.017214
# 1                      12.509000  ...      2   32   2003.084932     0.550855
# 2                      13.684000  ...      4   91   2003.246575     1.566493
# 3                      14.898000  ...      4   91   2003.246575     1.566493
# 4                      12.422501  ...      5  121   2003.328767     2.082919
# ...                          ...  ...    ...  ...           ...          ...
# 39976                  19.981024  ...      8  214   2024.581967     3.683840
# 39977                  19.166788  ...      9  245   2024.666667     4.217481
# 39978                  21.848916  ...      1    1   2024.000000     0.017214
# 39979                  22.521351  ...      1    1   2024.000000     0.017214
# 39980                  20.287560  ...     11  306   2024.833333     5.267547
#
#         doy_sin   doy_cos    x_cart    y_cart    z_cart  bottom_depth_m
# 0      0.017213  0.999852 -0.599256  0.311953 -0.737277            4926
# 1      0.523416  0.852078 -0.599256  0.311953 -0.737277            4926
# 2      0.999991  0.004304 -0.610578  0.317847 -0.725374            4396
# 3      0.999991  0.004304 -0.616032  0.307142 -0.725374            4558
# 4      0.871706 -0.490029 -0.632630  0.301749 -0.713250            4593
# ...         ...       ...       ...       ...       ...             ...
# 39976 -0.516062 -0.856551 -0.244716  0.826147 -0.507538            5126
# 39977 -0.880012 -0.474951 -0.244716  0.826147 -0.507538            5126
# 39978  0.017213  0.999852 -0.329731  0.796042 -0.507538            5018
# 39979  0.017213  0.999852 -0.343574  0.790166 -0.507538            4861
# 39980 -0.849817  0.527078 -0.854258  0.112465 -0.507538            1790
#
# [39981 rows x 34 columns]
