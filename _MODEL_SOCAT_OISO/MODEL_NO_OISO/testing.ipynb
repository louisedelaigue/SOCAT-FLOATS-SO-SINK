# %%
import pandas as pd


socat_path = (
        "/remote/unity/bgc-output/DELAIGUE/SOCAT-FLOATS-OSSE/"
    "_MODEL_SOCAT_OISO/MODEL_NO_OISO/processing_steps/"
    "SOCATv2025_SO_NO_OISO_clean_MLD_monthly_regridded_SLA.csv"
)


test = pd.read_csv(socat_path)

# %%
test
# Out:
#       month_center  lat_center  lon_center  depth    MLD  ARMOR3D_temperature  \
# 0       2000-02-01       -78.5      -177.5    0.0  15.00              -1.5435
# 1       2003-01-01       -78.5      -177.5    0.0  15.00              -1.7595
# 2       1996-12-01       -78.5      -176.5    0.0  21.45              -1.3300
# 3       1997-01-01       -78.5      -176.5    0.0  15.00              -0.9140
# 4       1997-02-01       -78.5      -176.5    0.0  15.30              -1.4415
# ...            ...         ...         ...    ...    ...                  ...
# 59273   2017-10-01       -30.5       178.5    0.0  31.30              18.9825
# 59274   2023-03-01       -30.5       178.5    0.0  29.00              23.0980
# 59275   2006-10-01       -30.5       179.5    0.0  25.30              18.6685
# 59276   2006-11-01       -30.5       179.5    0.0  20.45              20.1330
# 59277   2014-09-01       -30.5       179.5    0.0  59.15              18.0765
#
#        ARMOR3D_salinity  fco2_rec_median  SOCAT_temperature  SOCAT_salinity  \
# 0               34.0415         234.9770            -1.4100         34.0600
# 1               34.1485         395.2135            -1.6100         34.1990
# 2               34.1685         150.2790            -0.9050         33.8050
# 3               34.1450         127.7700            -0.3400         33.8900
# 4               34.0665         170.1675            -0.8850         33.9900
# ...                 ...              ...                ...             ...
# 59273           35.7375         345.0650            19.4900         35.8350
# 59274           35.3425         396.9780            23.0245         35.2675
# 59275           35.7260         326.3815            18.7015         35.6610
# 59276           35.7830         340.8620            20.5140         35.6780
# 59277           35.6240         340.4870            17.8310         35.6325
#
#        fco2_rec_count  sla_median
# 0                17.0    0.036081
# 1                36.0    0.055584
# 2                 2.0    0.003781
# 3               253.0    0.003952
# 4                62.0    0.004262
# ...               ...         ...
# 59273           120.0    0.041702
# 59274            92.0    0.100465
# 59275           114.0   -0.025308
# 59276            68.0    0.014652
# 59277            30.0    0.061463
#
# [59278 rows x 12 columns]
